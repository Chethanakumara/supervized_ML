# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('House Price Prediction Dataset.csv',index_col='Id')
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# Id
# 1     1360         5          4       3       1970  Downtown  Excellent
# 2     4272         5          4       3       1958  Downtown  Excellent
# 3     3592         2          2       3       1938  Downtown       Good
# 4      966         4          2       2       1902  Suburban       Fair
# 5     4926         1          4       2       1975  Downtown       Fair
# ...    ...       ...        ...     ...        ...       ...        ...
# 1996  4994         5          4       3       1923  Suburban       Poor
# 1997  3046         5          2       1       2019  Suburban       Poor
# 1998  1062         5          1       2       1903     Rural       Poor
# 1999  4062         3          1       2       1936     Urban  Excellent
# 2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# Id
# 1        No  149919
# 2        No  424998
# 3        No  266746
# ...

# %%
df.describe()
# Out:
#               Area     Bedrooms   Bathrooms       Floors    YearBuilt  \
# count  2000.000000  2000.000000  2000.00000  2000.000000  2000.000000
# mean   2786.209500     3.003500     2.55250     1.993500  1961.446000
# std    1295.146799     1.424606     1.10899     0.809188    35.926695
# min     501.000000     1.000000     1.00000     1.000000  1900.000000
# 25%    1653.000000     2.000000     2.00000     1.000000  1930.000000
# 50%    2833.000000     3.000000     3.00000     2.000000  1961.000000
# 75%    3887.500000     4.000000     4.00000     3.000000  1993.000000
# max    4999.000000     5.000000     4.00000     3.000000  2023.000000
#
#                Price
# count    2000.000000
# mean   537676.855000
# std    276428.845719
# min     50005.000000
# 25%    300098.000000
# 50%    539254.000000
# 75%    780086.000000
# max    999656.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 1 to 2000
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       2000 non-null   int64
#  1   Bedrooms   2000 non-null   int64
#  2   Bathrooms  2000 non-null   int64
#  3   Floors     2000 non-null   int64
#  4   YearBuilt  2000 non-null   int64
#  5   Location   2000 non-null   object
#  6   Condition  2000 non-null   object
#  7   Garage     2000 non-null   object
#  8   Price      2000 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 156.2+ KB

# %%
rd=df.iloc[1000,:5]

# %%
print(rd)
# Out:
# Area         4453
# Bedrooms        5
# Bathrooms       1
# Floors          2
# YearBuilt    1946
# Name: 1001, dtype: object

# %%
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# Id
# 1     1360         5          4       3       1970  Downtown  Excellent
# 2     4272         5          4       3       1958  Downtown  Excellent
# 3     3592         2          2       3       1938  Downtown       Good
# 4      966         4          2       2       1902  Suburban       Fair
# 5     4926         1          4       2       1975  Downtown       Fair
# ...    ...       ...        ...     ...        ...       ...        ...
# 1996  4994         5          4       3       1923  Suburban       Poor
# 1997  3046         5          2       1       2019  Suburban       Poor
# 1998  1062         5          1       2       1903     Rural       Poor
# 1999  4062         3          1       2       1936     Urban  Excellent
# 2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# Id
# 1        No  149919
# 2        No  424998
# 3        No  266746
# ...

# %%
dro= df.drop(['Location',	'Condition','Garage'],axis=1)
dro
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt   Price
# Id
# 1     1360         5          4       3       1970  149919
# 2     4272         5          4       3       1958  424998
# 3     3592         2          2       3       1938  266746
# 4      966         4          2       2       1902  244020
# 5     4926         1          4       2       1975  636056
# ...    ...       ...        ...     ...        ...     ...
# 1996  4994         5          4       3       1923  295620
# 1997  3046         5          2       1       2019  580929
# 1998  1062         5          1       2       1903  476925
# 1999  4062         3          1       2       1936  161119
# 2000  2989         5          1       3       1903  482525
#
# [2000 rows x 6 columns]

# %%
use = dro.iloc [:1000,:]
use
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt   Price
# Id
# 1     1360         5          4       3       1970  149919
# 2     4272         5          4       3       1958  424998
# 3     3592         2          2       3       1938  266746
# 4      966         4          2       2       1902  244020
# 5     4926         1          4       2       1975  636056
# ...    ...       ...        ...     ...        ...     ...
# 996   3261         2          4       3       1997  556357
# 997   3179         1          4       2       1929   58539
# 998   2606         5          3       1       1971  182335
# 999   4723         4          3       2       2002  456521
# 1000  3268         1          2       2       1962  890249
#
# [1000 rows x 6 columns]

# %%
sb.histplot(use['Area'], kde=True, color='r')
plt.title("AREA")
plt.show()

# %%
sb.boxplot(x='Bathrooms',data=use)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.countplot(x=use['Bathrooms'], color='y')
plt.title("Count of Bathrooms Values")
plt.show()

# %%
sb.countplot(x='Bathrooms', data=df, palette='pastel')
plt.title("Category Counts for Bathrooms")
plt.show()
# Out:
# C:\Users\chethan kiruvase\AppData\Local\Temp\ipykernel_15200\2646168903.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x='Bathrooms', data=df, palette='pastel')

# %%
use['Bathrooms'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Category Distribution")
plt.show()

# %%
df
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# Id
# 1     1360         5          4       3       1970  Downtown  Excellent
# 2     4272         5          4       3       1958  Downtown  Excellent
# 3     3592         2          2       3       1938  Downtown       Good
# 4      966         4          2       2       1902  Suburban       Fair
# 5     4926         1          4       2       1975  Downtown       Fair
# ...    ...       ...        ...     ...        ...       ...        ...
# 1996  4994         5          4       3       1923  Suburban       Poor
# 1997  3046         5          2       1       2019  Suburban       Poor
# 1998  1062         5          1       2       1903     Rural       Poor
# 1999  4062         3          1       2       1936     Urban  Excellent
# 2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# Id
# 1        No  149919
# 2        No  424998
# 3        No  266746
# ...

# %%
order = ['Poor', 'Good', 'Fair','Excellent']
sb.countplot(x='Condition', data=df, order=order)
plt.title("Ordered Category Distribution")
plt.show()

# %%
sb.countplot(x='Garage', data=df)
plt.title("Binary Target Distribution")
plt.show()

# %%
n_c= df.select_dtypes(include=['int64','float64']).columns

# %%
for col in n_c:
    plt.figure(figsize=(6,4))
    sb.histplot(df[col], kde=True, color='teal')
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sb.countplot(x=col, data=df, palette='pastel')
    plt.title(f"Count Plot of {col}")
    plt.show()
# Out:
# C:\Users\chethan kiruvase\AppData\Local\Temp\ipykernel_15200\997629614.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=col, data=df, palette='pastel')
# C:\Users\chethan kiruvase\AppData\Local\Temp\ipykernel_15200\997629614.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=col, data=df, palette='pastel')
# C:\Users\chethan kiruvase\AppData\Local\Temp\ipykernel_15200\997629614.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=col, data=df, palette='pastel')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
use
# Out:
#       Area  Bedrooms  Bathrooms  Floors  YearBuilt   Price
# Id
# 1     1360         5          4       3       1970  149919
# 2     4272         5          4       3       1958  424998
# 3     3592         2          2       3       1938  266746
# 4      966         4          2       2       1902  244020
# 5     4926         1          4       2       1975  636056
# ...    ...       ...        ...     ...        ...     ...
# 996   3261         2          4       3       1997  556357
# 997   3179         1          4       2       1929   58539
# 998   2606         5          3       1       1971  182335
# 999   4723         4          3       2       2002  456521
# 1000  3268         1          2       2       1962  890249
#
# [1000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x = use[['Area']]
y = use['Price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y ,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
scaler = StandardScaler()

# Fit on training data and transform both
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Model with scaling
model2 = LinearRegression()
model2.fit(X_train_scaled, y_train)
y_pred2 = model2.predict(X_test_scaled)

print("🚀 Accuracy with StandardScaler:", accuracy_score(y_test, y_pred2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 12
#       9 model2.fit(X_train_scaled, y_train)
#      10 y_pred2 = model2.predict(X_test_scaled)
# ---> 12 print("🚀 Accuracy with StandardScaler:", accuracy_score(y_test, y_pred2))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...
